# %% [markdown]
# (In order to load the stylesheet of this notebook, execute the last code cell in this notebook)

# %% [markdown]
# # Clustering the data from the Mayor's 24-hour hotline in Boston

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this assignment, we will do a clustering analysis on the 311 calls that we used in the previous homework. We will focus on choosing a value for k, clustering based on multiple features and detecting outliers.
#
# ---------------------------

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import sklearn.metrics as metrics
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import numpy as np
import scipy as sp

# %%
#boston = pd.read_csv('../Homework-2/cases_2015.csv')
boston = pd.read_csv('../Homework-2/cases_2015.csv', parse_dates=['OPEN_DT', 'TARGET_DT', 'CLOSED_DT'])

# %% [markdown]
# ## Step 1. Simple clustering

# %% [markdown]
# The first thing that we will try is to cluster the geolocation data of the calls. The geolocation of a record consists of a pair `(latitude, longitude)`, which represents the position of the record on the map. Since the dataset that we have spans only a small geographic location, i.e. Boston, we will use the Euclidean distance when measuring how close two points are. Techinically, we should pick a [projection](https://github.com/mbostock/d3/wiki/Geo-Projections) in order to transform the data into 2d, and measure  the Euclidean distance in the projected space.

# %% [markdown]
# Since we are dealing with numeric data, we might consider centering and normalizing them. In order to do that, check the [StandardScaler](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler) from `scikit-learn`.

# %% [markdown]
# For example, the result of a clustering with 10 clusters is the following:
#
#
# ![A clustering of the locations of the calls for k=10](clusters10.png)

# %% [markdown]
# Filter the dataset to get the latitude and longitude, transform it as required and run the k-means clustering algorithm. Argue about the number of clusters you used. **(pts 50)**

# %%
Y = boston[["LATITUDE"]]
X = boston[["LONGITUDE"]]
#euclidean_dists = metrics.euclidean_distances(locations)

def evaluate_clusters(X,max_clusters):
    error = np.zeros(max_clusters+1)
    error[0] = 0;
    for k in range(1,max_clusters+1):
        kmeans = KMeans(init='k-means++', n_clusters=k, n_init=10)
        kmeans.fit_predict(X)
        error[k] = kmeans.inertia_

    plt.plot(range(1,len(error)),error[1:])
    plt.xlabel('Number of clusters')
    plt.ylabel('Error')

scaled_X = StandardScaler().fit_transform(X)
scaled_Y = StandardScaler().fit_transform(Y)
scaled_XY = np.concatenate((scaled_X, scaled_Y), axis=1)

scaled_XY_kmeans = KMeans(init='k-means++', n_clusters=20, n_init=10)
scaled_XY_kmeans.fit_predict(scaled_XY)
centroids = scaled_XY_kmeans.cluster_centers_
scaled_XY_labels = scaled_XY_kmeans.labels_
error = scaled_XY_kmeans.inertia_

fig, ax = plt.subplots(1,1,figsize=(10,10))
# I have 10 clusters, so I need 10 colors. Each colormap can produce 10 colors
# so I am mixing two colormaps that I tested that work well together
cmap = sns.color_palette("bright", n_colors=5)
cmap.extend(sns.hls_palette(n_colors=15, h=0.7, l=0.4, s=0.8))

# for each label, isolate the points of that label and plot them with the same color
for i, label in enumerate(set(scaled_XY_labels)):
    point_indices = np.where(scaled_XY_labels == label)[0]
    point_indices = point_indices.tolist()
    plt.scatter(scaled_XY[point_indices][:,0], scaled_XY[point_indices][:,1], s=28, alpha=0.3, c=cmap[i], marker='+')

# %%
print scaled_XY
# Out:
# [[ 0.56137468  0.95700633]
#  [-0.27309872  0.66876329]
#  [-0.27309872  0.66876329]
#  ...,
#  [-0.23926872 -1.43252847]
#  [ 0.73334387  1.01465494]
#  [-0.23926872 -1.42099874]]

# %%
evaluate_clusters(scaled_XY, 25)

# %% [markdown]
# -----

# %% [markdown]
# ## Step 2. Using multiple features

# %% [markdown]
# The next step in our analysis is to use more features than just the geolocation of a record (whose clustering only gives us information about the neighborhoods, which should not be a huge revelation!) Filter the dataset to get more features, transform them as required and compute another clustering. You should argue about the quality of your clustering and use domain knowledge (i.e. the fact that you are locals) to explore the clusters you produced and present them to the reader. **(30 pts)**

# %%
print boston.info()
print boston.TYPE
print boston.QUEUE
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46698 entries, 0 to 46697
# Data columns (total 33 columns):
# CASE_ENQUIRY_ID                   46698 non-null int64
# OPEN_DT                           46698 non-null datetime64[ns]
# TARGET_DT                         41129 non-null datetime64[ns]
# CLOSED_DT                         35141 non-null datetime64[ns]
# OnTime_Status                     46694 non-null object
# CASE_STATUS                       46698 non-null object
# CLOSURE_REASON                    35175 non-null object
# CASE_TITLE                        46698 non-null object
# SUBJECT                           46698 non-null object
# REASON                            46698 non-null object
# TYPE                              46698 non-null object
# QUEUE                             46698 non-null object
# Department                        46698 non-null object
# SubmittedPhoto                    7245 non-null object
# ClosedPhoto                       1217 non-null object
# Location                          44442 non-null object
# fire_district                     44229 non-null float64
# pwd_district                      44338 non-null object
# city_council_district             44431 non-null float64
# police_district                   44358 non-null object
# neighborhood                      44402 non-null object
# neighborhood_services_district    44431 non-null float64
# ward                              44438 non-null object
# precinct                          44297 non-null float64
# land_usage                        33332 non-null object
# LOCATION_STREET_NAME              44442 non-null object
# LOCATION_ZIPCODE                  35291 non-null float64
# Property_Type                     44442 non-null object
# Property_ID                       44442 non-null float64
# LATITUDE                          46698 non-null float64
# LONGITUDE                         46698 non-null float64
# Source                            46698 non-null object
# Geocoded_Location                 46698 non-null object
# dtypes: datetime64[ns](3), float64(8), int64(1), object(21)
# memory usage: 12.1+ MB
# None
# 0                       Notification
# 1               Street Light Outages
# 2               Street Light Outages
# 3                       Animal Found
# 4                       Notification
# 5                       Notification
# 6       Requests for Street Cleaning
# 7                        Animal Lost
# 8       Requests for Street Cleaning
# 9                       Animal Found
# 10      Requests for Street Cleaning
# 11    Heat - Excessive  Insufficient
# 12               Parking Enforcement
# 13             Illegal Rooming House
# 14                   Watermain Break
# ...
# 46683                                       Sign Repair
# 46684                              Street Light Outages
# 46685                              Street Light Outages
# 46686                              Street Light Outages
# 46687                          Request for Snow Plowing
# 46688       Missed Trash/Recycling/Yard Waste/Bulk Item
# 46689                              Misc. Snow Complaint
# 46690                                      Snow Removal
# 46691                          Request for Snow Plowing
# 46692                                      Snow Removal
# 46693                          Request for Snow Plowing
# 46694    Request for Snow Plowing (Emergency Responder)
# 46695                                      Snow Removal
# 46696          General Comments For a Program or Policy
# 46697                              Misc. Snow Complaint
# Name: TYPE, Length: 46698, dtype: object
# 0                  INFO09_Current Events
# 1              PWDx_Street Light Outages
# 2              PWDx_Street Light Outages
# 3                       ANML02_LostFound
# 4                  INFO09_Current Events
# 5                  INFO09_Current Events
# 6     PWDx_District 07: South Dorchester
# 7                       ANML02_LostFound
# 8            PWDx_District 08: Hyde Park
# 9                       ANML02_LostFound
# 10            PWDx_District 1C: Downtown
# 11                ISD_Housing (INTERNAL)
# 12              BTDT_Parking Enforcement
# 13               ISD_Building (INTERNAL)
# 14                        BWSC_All Cases
# ...
# 46683                         INFO_Reallocation From Dept
# 46684                           PWDx_Street Light Outages
# 46685                           PWDx_Street Light Outages
# 46686                           PWDx_Street Light Outages
# 46687                  PWDx_District 04: Allston/Brighton
# 46688    PWDx_Missed Trash\Recycling\Yard Waste\Bulk Item
# 46689                  PWDx_District 07: South Dorchester
# 46690                     ISD_Code Enforcement (INTERNAL)
# 46691                  PWDx_District 07: South Dorchester
# 46692                     ISD_Code Enforcement (INTERNAL)
# 46693                     PWDx_District 02: Jamaica Plain
# 46694                     PWDx_District 02: Jamaica Plain
# 46695                     ISD_Code Enforcement (INTERNAL)
# 46696                               PWDx_General Comments
# 46697                  PWDx_District 07: South Dorchester
# Name: QUEUE, Length: 46698, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#madxdf maximum inverse document frequency
vectorizer = TfidfVectorizer(stop_words='english', min_df=4, max_df=0.8)
data = vectorizer.fit_transform(boston.TYPE)
evaluate_clusters(data, 25)

# %%
from sklearn.feature_extraction import DictVectorizer

TYPE_ZIPCODE = boston[["TYPE", "LOCATION_ZIPCODE"]]
print TYPE_ZIPCODE
TYPE_ZIPCODE = TYPE_ZIPCODE.to_dict()
print TYPE_ZIPCODE
v = DictVectorizer(sparse=False)
TYPE_ZIPCODE_T = v.fit_transform(TYPE_ZIPCODE)
print TYPE_ZIPCODE_T
# Out:
#                                                  TYPE  LOCATION_ZIPCODE
# 0                                        Notification              2108
# 1                                Street Light Outages              2215
# 2                                Street Light Outages              2215
# 3                                        Animal Found              2132
# 4                                        Notification              2125
# 5                                        Notification              2125
# 6                        Requests for Street Cleaning              2124
# 7                                         Animal Lost              2124
# 8                        Requests for Street Cleaning              2136
# 9                                        Animal Found              2122
# 10                       Requests for Street Cleaning               NaN
# 11                     Heat - Excessive  Insufficient              2118
# 12                                Parking Enforcement              2120
# 13                              Illegal Rooming House              2115
# 14                                    Watermain Break              2132
# 15                     Schedule a Bulk Item Pickup SS              2129
# 16                       Requests for Street Cleaning              2119
# 17                     Heat - Excessive  Insufficient              2118
# 18                        Schedule a Bulk Item Pickup              2119
# 19                              Traffic Signal Repair               NaN
# 20                         Request for Pothole Repair               NaN
# 21        Missed Trash/Recycling/Yard Waste/Bulk Item              2119
# 22                       Requests for Street Cleaning              2135
# 23                         Request for Pothole Repair              2108
# 24                             Utility Casting Repair              2108
# 25                         Request for Pothole Repair              2108
# 26                         Request for Pothole Repair              2108
# 27                         Request for Pothole Repair              2108
# 28        Missed Trash/Recycling/Yard Waste/Bulk Item              2124
# 29                                        Sign Repair              2128
# ...                                               ...               ...
# 46668                      Request for Pothole Repair              2127
# 46669  Request for Snow Plowing (Emergency Responder)              2118
# 46670                                    Snow Removal              2127
# 46671                        Request for Snow Plowing               NaN
# 46672                        Request for Snow Plowing              2118
# 46673                        Request for Snow Plowing              2118
# 46674                  Heat - Excessive  Insufficient              2124
# 46675                                    Snow Removal              2124
# 46676                                    Snow Removal               NaN
# 46677                        Request for Snow Plowing              2127
# 46678                        Request for Snow Plowing              2135
# 46679                        Request for Snow Plowing               NaN
# 46680                            Street Light Outages              2136
# 46681                            Street Light Outages              2108
# 46682                            Street Light Outages               NaN
# 46683                                     Sign Repair              2130
# 46684                            Street Light Outages              2129
# 46685                            Street Light Outages              2115
# 46686                            Street Light Outages              2108
# 46687                        Request for Snow Plowing              2135
# 46688     Missed Trash/Recycling/Yard Waste/Bulk Item              2118
# 46689                            Misc. Snow Complaint              2126
# 46690                                    Snow Removal              2124
# 46691                        Request for Snow Plowing              2126
# 46692                                    Snow Removal              2125
# 46693                        Request for Snow Plowing              2130
# 46694  Request for Snow Plowing (Emergency Responder)              2131
# 46695                                    Snow Removal              2126
# 46696        General Comments For a Program or Policy               NaN
# 46697                            Misc. Snow Complaint              2126
#
# [46698 rows x 2 columns]
# {'LOCATION_ZIPCODE': {0: 2108.0, 1: 2215.0, 2: 2215.0, 3: 2132.0, 4: 2125.0, 5: 2125.0, 6: 2124.0, 7: 2124.0, 8: 2136.0, 9: 2122.0, 10: nan, 11: 2118.0, 12: 2120.0, 13: 2115.0, 14: 2132.0, 15: 2129.0, 16: 2119.0, 17: 2118.0, 18: 2119.0, 19: nan, 20: nan, 21: 2119.0, 22: 2135.0, 23: 2108.0, 24: 2108.0, 25: 2108.0, 26: 2108.0, 27: 2108.0, 28: 2124.0, 29: 2128.0, 30: 2118.0, 31: 2127.0, 32: 2130.0, 33: nan, 34: 2116.0, 35: 2119.0, 36: 2128.0, 37: 2135.0, 38: 2132.0, 39: 2129.0, 40: 2127.0, 41: nan, 42: 2135.0, 43: 2127.0, 44: nan, 45: 2131.0, 46: nan, 47: nan, 48: 2135.0, 49: 2135.0, 50: 2121.0, 51: 2113.0, 52: 2132.0, 53: nan, 54: 2136.0, 55: 2113.0, 56: nan, 57: 2127.0, 58: nan, 59: 2109.0, 60: 2125.0, 61: 2129.0, 62: nan, 63: nan, 64: 2110.0, 65: 2130.0, 66: 2124.0, 67: 2130.0, 68: nan, 69: 2127.0, 70: 2127.0, 71: 2127.0, 72: 2127.0, 73: 2120.0, 74: 2132.0, 75: 2116.0, 76: 2121.0, 77: 2118.0, 78: 2134.0, 79: 2135.0, 80: 2127.0, 81: 2134.0, 82: 2115.0, 83: nan, 84: 2132.0, 85: 2119.0, 86: 2108.0, 87: 2134.0, 88: 2116.0, 89: nan, 90: 2135.0, 91: nan, 92: 2118.0, 93: 2118.0, 94: 2118.0, 95: 2130.0, 96: nan, 97: 2130.0, 98: 2113.0, 99: 2129.0, 100: 2124.0, 101: 2132.0, 102: 2130.0, 103: nan, 104: 2130.0, 105: 2130.0, 106: 2122.0, 107: 2131.0, 108: 2119.0, 109: 2131.0, 110: 2130.0, 111: 2111.0, 112: 2132.0, 113: 2113.0, 114: 2113.0, 115: 2118.0, 116: nan, 117: 2124.0, 118: 2132.0, 119: 2130.0, 120: 2124.0, 121: 2130.0, 122: 2119.0, 123: nan, 124: nan, 125: 2215.0, 126: 2136.0, 127: 2126.0, 128: nan, 129: nan, 130: 2210.0, 131: 2210.0, 132: 2210.0, 133: 2127.0, 134: nan, 135: 2127.0, 136: 2129.0, 137: 2129.0, 138: 2127.0, 139: 2128.0, 140: 2127.0, 141: 2127.0, 142: 2128.0, 143: 2127.0, 144: 2127.0, 145: 2125.0, 146: 2127.0, 147: 2121.0, 148: 2116.0, 149: 2116.0, 150: 2116.0, 151: 2127.0, 152: 2127.0, 153: 2125.0, 154: nan, 155: nan, 156: 2127.0, 157: 2210.0, 158: 2127.0, 159: nan, 160: 2128.0, 161: 2127.0, 162: nan, 163: 2127.0, 164: 2108.0, 165: 2125.0, 166: 2131.0, 167: nan, 168: nan, 169: 2127.0, 170: 2127.0, 171: 2127.0, 172: 2127.0, 173: nan, 174: 2127.0, 175: 2131.0, 176: 2124.0, 177: nan, 178: 2135.0, 179: 2130.0, 180: 2120.0, 181: nan, 182: 2135.0, 183: 2127.0, 184: 2135.0, 185: nan, 186: nan, 187: nan, 188: 2127.0, 189: 2127.0, 190: nan, 191: 2127.0, 192: 2128.0, 193: 2127.0, 194: nan, 195: 2127.0, 196: nan, 197: nan, 198: 2127.0, 199: 2127.0, 200: 2125.0, 201: 2135.0, 202: 2126.0, 203: nan, 204: 2134.0, 205: 2135.0, 206: 2134.0, 207: 2118.0, 208: nan, 209: 2125.0, 210: 2128.0, 211: 2134.0, 212: 2134.0, 213: 2127.0, 214: 2122.0, 215: 2122.0, 216: 2127.0, 217: 2128.0, 218: 2127.0, 219: nan, 220: 2127.0, 221: 2136.0, 222: 2135.0, 223: nan, 224: nan, 225: nan, 226: nan, 227: 2127.0, 228: 2124.0, 229: 2128.0, 230: nan, 231: 2127.0, 232: 2131.0, 233: 2135.0, 234: 2127.0, 235: 2125.0, 236: 2127.0, 237: 2132.0, 238: 2127.0, 239: 2127.0, 240: 2122.0, 241: 2122.0, 242: nan, 243: 2124.0, 244: nan, 245: 2130.0, 246: 2135.0, 247: nan, 248: 2129.0, 249: 2135.0, 250: 2127.0, 251: 2125.0, 252: 2135.0, 253: 2122.0, 254: nan, 255: 2124.0, 256: 2128.0, 257: 2215.0, 258: 2127.0, 259: 2132.0, 260: 2127.0, 261: 2127.0, 262: 2127.0, 263: nan, 264: 2127.0, 265: nan, 266: nan, 267: 2120.0, 268: 2127.0, 269: nan, 270: nan, 271: 2127.0, 272: nan, 273: 2127.0, 274: 2128.0, 275: 2113.0, 276: 2127.0, 277: nan, 278: 2132.0, 279: 2131.0, 280: 2124.0, 281: nan, 282: 2118.0, 283: nan, 284: 2118.0, 285: 2132.0, 286: 2113.0, 287: 2135.0, 288: 2130.0, 289: 2127.0, 290: 2118.0, 291: 2121.0, 292: 2132.0, 293: 2136.0, 294: 2126.0, 295: 2136.0, 296: nan, 297: 2118.0, 298: 2125.0, 299: 2130.0, 300: 2134.0, 301: 2121.0, 302: 2136.0, 303: 2134.0, 304: 2131.0, 305: nan, 306: 2126.0, 307: 2127.0, 308: 2134.0, 309: 2127.0, 310: 2124.0, 311: 2127.0, 312: 2127.0, 313: 2116.0, 314: 2127.0, 315: nan, 316: 2134.0, 317: 2115.0, 318: 2119.0, 319: 2132.0, 320: nan, 321: 2136.0, 322: 2127.0, 323: 2128.0, 324: nan, 325: nan, 326: 2127.0, 327: 2135.0, 328: 2127.0, 329: 2125.0, 33 ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-aa7dd1d29188> in <module>()
#       6 print TYPE_ZIPCODE
#       7 v = DictVectorizer(sparse=False)
# ----> 8 TYPE_ZIPCODE_T = v.fit_transform(TYPE_ZIPCODE)
#       9 print TYPE_ZIPCODE_T
#
# //anaconda/lib/python2.7/site-packages/sklearn/feature_extraction/dict_vectorizer.pyc in fit_transform(self, X, y)
#     140         X = _tosequence(X)
#     141         self.fit(X)
# --> 142         return self.transform(X)
#     143
#     144     def inverse_transform(self, X, dict_type=dict):
#
# //anaconda/lib/python2.7/site-packages/sklearn/feature_extraction/dict_vectorizer.pyc in transform(self, X, y)
#     256                         v = 1
#     257                     try:
# --> 258                         Xa[i, vocab[f]] = dtype(v)
#     259                     except KeyError:
#     260                         pass
#
# TypeError: float() argument must be a string or a number

# %%
sources = boston.Source.unique()
#print sources
LU = boston[:]
ZIPCODES = boston[["LOCATION_ZIPCODE"]]
ZIPCODES.fillna(value=0, inplace=True)
#print ZIPCODES.shape
#evaluate_clusters(ZIPCODES, 10)

CASES = boston[["CASE_TITLE"]]
CASES.fillna(value=0, inplace=True)
#print CASES.shape
#evaluate_clusters(CASES, 10)

ZIPCODES_kmeans = KMeans(init='k-means++', n_clusters=15, n_init=10)
ZIPCODES_kmeans.fit_predict(ZIPCODES)
centroids = ZIPCODES_kmeans.cluster_centers_
ZIPCODES_labels = ZIPCODES_kmeans.labels_
error = ZIPCODES_kmeans.inertia_

#print ZIPCODES_labels

#LU_labels = pd.Categorical.from_array(LU['LOCATION_ZIPCODE'])
#LU['cluster_label'] = LU_labels.labels
#LU = LU_labels.labels

#LT_labels = pd.Categorical.from_array(boston['CASE_TITLE'])
#LT = LT_labels.labels
LT = boston.CASE_TITLE
LT.fillna(value="", inplace=True)
LT_data = vectorizer.fit_transform(LT)

#mdata = pd.merge(ZIPCODES, LT)
#mdata = pd.DataFrame(ZIPCODES, LT)
mdata = boston[['TYPE', 'LOCATION_ZIPCODE']]
mdata_labels = pd.Categorical.from_array(mdata['TYPE'])
mdata['TYPE'] = mdata_labels.labels
mdata.fillna(value=0, inplace=True)
#print mdata

#scaled_case_title = StandardScaler().fit_transform(mdata[['CASE_TITLE']])
#scaled_zip = StandardScaler().fit_transform(mdata[['LOCATION_ZIPCODE']])
#mdata = np.concatenate((scaled_case_title, scaled_zip), axis=1)
#print mdata

case_type = mdata[['TYPE']]
zipcode = mdata[['LOCATION_ZIPCODE']]
mdata = np.concatenate((case_type, zipcode), axis=1)
#print mdata

mdata_kmeans = KMeans(init='k-means++', n_clusters=10, n_init=10)
mdata_kmeans.fit_predict(mdata)
mdata_centroids = mdata_kmeans.cluster_centers_
mdata_labels = mdata_kmeans.labels_
error = mdata_kmeans.inertia_

fig3, ax3 = plt.subplots(1,1,figsize=(10,10))
cmap = sns.color_palette("bright", n_colors=5)
cmap.extend(sns.hls_palette(n_colors=15, h=0.7, l=0.4, s=0.8))

# for each label, isolate the points of that label and plot them with the same color
for i, label in enumerate(set(mdata_labels)):
    point_indices = np.where(mdata_labels == label)[0]
    point_indices = point_indices.tolist()
    print min(point_indices)
    print max(point_indices)
    plt.scatter(mdata[point_indices][:,0], mdata[point_indices][:,1], s=28, alpha=0.3, c=cmap[i], marker='+')
# Out:
# 244
# 46650
# 6
# 46694
# 0
# 46697
# 41
# 46696
# 10
# 46679
# 3
# 46674
# 14
# 46695
# 1
# 46621
# 1169
# 41587
# 19
# 46682

# %%
print len(boston.TYPE.unique())
types = boston.groupby("TYPE").size()
types.sort(ascending=False)
print types
# Out:
# 170
# TYPE
# Request for Snow Plowing                          18625
# Snow Removal                                       7434
# Missed Trash/Recycling/Yard Waste/Bulk Item        3800
# General Comments For a Program or Policy           1417
# Requests for Street Cleaning                       1088
# Street Light Outages                                847
# Request for Pothole Repair                          808
# Misc. Snow Complaint                                768
# Schedule a Bulk Item Pickup                         747
# Heat - Excessive  Insufficient                      519
# Empty Litter Basket                                 507
# Traffic Signal Repair                               465
# Request for Snow Plowing (Emergency Responder)      464
# Parking Enforcement                                 458
# PWD Graffiti                                        449
# ...
# Cemetery Maintenance Request                 2
# No-Tow Complaint Confirmation                2
# Mechanical                                   2
# Municipal Parking Lot Complaints             2
# CE Collection                                1
# No Utilities - Food Establishment - Water    1
# Planting                                     1
# Water in Gas - High Priority                 1
# Rental Unit Delivery Conditions              1
# No Price on Gas/Wrong Price                  1
# Bridge Maintenance                           1
# Automotive Noise Disturbance                 1
# Mosquitoes (West Nile)                       1
# Install New Lighting                         1
# Rat Bite                                     1
# Length: 170, dtype: int64

# %%
evaluate_clusters(mdata, 25)

# %%
all_case_titles = boston.groupby('CASE_TITLE').size()
all_case_titles.sort(ascending=False)
top_case_titles = all_case_titles[:10]

d = boston[boston.CASE_TITLE.apply(lambda t: t in top_case_titles)]
d = d[boston.CASE_STATUS == "Closed"]
d["DURATION"] = d.CLOSED_DT - d.OPEN_DT
d["DURATION"] = d["DURATION"].apply(lambda d: d/np.timedelta64(1, 'm'))

s = np.array(d[['DURATION']])
print type(s[0][0])

# Code:
# 1. Snow
# 2. Street
# 3. Heat
# 4. Waste
case_groups = {1: ["Request for Snow Plowing", "Snow Removal", \
               "Misc. Snow Complaint", "Request for Snow Plowing (Emergency Responder)"],\
               2: ["Requests for Street Cleaning", "Request for Pothole Repair", "Traffic Signal Repair"],\
               3: ["Heat - Excessive Insufficient"],\
               4: ["Schedule a Bulk Item Pickup", "Empty Litter Basket"]}

d["CG_LABEL"] = 0
for l in case_groups:
    cur = d[d.CASE_TITLE.apply(lambda t: t in case_groups[l])]
    cur["CG_LABEL"] = l
    
print new.head()
    

#print d.info()
#print d[d.CASE_TITLE.apply(lambda t: t in case_groups[1])].head()

#ndata = np.concatenate((s, o), axis=1)
#print mdata

ndata_kmeans = KMeans(init='k-means++', n_clusters=10, n_init=10)
ndata_kmeans.fit_predict(ndata)
ndata_centroids = ndata_kmeans.cluster_centers_
ndata_labels = ndata_kmeans.labels_
error = ndata_kmeans.inertia_

#print mdata_labels
#print len(mdata)
#print mdata.shape
#print mdata
#print mdata[0].shape

fig4, ax4 = plt.subplots(1,1,figsize=(10,10))
# I have 10 clusters, so I need 10 colors. Each colormap can produce 10 colors
# so I am mixing two colormaps that I tested that work well together
cmap = sns.color_palette("bright", n_colors=5)
cmap.extend(sns.hls_palette(n_colors=15, h=0.7, l=0.4, s=0.8))

# for each label, isolate the points of that label and plot them with the same color
for i, label in enumerate(set(ndata_labels)):
    point_indices = np.where(ndata_labels == label)[0]
    point_indices = point_indices.tolist()
    plt.scatter(ndata[point_indices][:,0], ndata[point_indices][:,1], s=28, alpha=0.3, c=cmap[i], marker='+')
#boston[boston.CASE_TITLE:]
# Out:
#   File "<ipython-input-241-358b6a4994b4>", line 21
#     new = np.array[]
#                    ^
# SyntaxError: invalid syntax

# %%
snow_cases = boston[boston.CASE_TITLE.apply(lambda t: 'snow' in str(t).lower())]
snow_cases_Y = snow_cases[["LONGITUDE"]]
snow_cases_X = snow_cases[["LATITUDE"]]

scaled_snow_cases_X = StandardScaler().fit_transform(snow_cases_X)
scaled_snow_cases_Y = StandardScaler().fit_transform(snow_cases_Y)
scaled_snow_cases_XY = np.concatenate((scaled_snow_cases_X, scaled_snow_cases_Y), axis=1)

scaled_snow_cases_XY_kmeans = KMeans(init='k-means++', n_clusters=20, n_init=10)
scaled_snow_cases_XY_kmeans.fit_predict(scaled_snow_cases_XY)
snow_cases_centroids = scaled_snow_cases_XY_kmeans.cluster_centers_
scaled_snow_cases_XY_labels = scaled_snow_cases_XY_kmeans.labels_
error = scaled_snow_cases_XY_kmeans.inertia_

fig2, ax2 = plt.subplots(1,1,figsize=(10,10))
# I have 10 clusters, so I need 10 colors. Each colormap can produce 10 colors
# so I am mixing two colormaps that I tested that work well together
cmap = sns.color_palette("bright", n_colors=5)
cmap.extend(sns.hls_palette(n_colors=15, h=0.7, l=0.4, s=0.8))

# for each label, isolate the points of that label and plot them with the same color
for i, label in enumerate(set(scaled_snow_cases_XY_labels)):
    point_indices = np.where(scaled_snow_cases_XY_labels == label)[0]
    point_indices = point_indices.tolist()
    plt.scatter(scaled_snow_cases_XY[point_indices][:,0], scaled_snow_cases_XY[point_indices][:,1], s=28, alpha=0.3, c=cmap[i], marker='+')
# Out:
#        LONGITUDE
# 42      -71.1579
# 83      -71.1687
# 116     -71.1092
# 409     -71.1248
# 412     -71.0732
# 509     -71.0893
# 602     -71.0889
# 722     -71.1001
# 725     -71.0652
# 728     -71.0835
# 730     -71.1147
# 732     -71.0627
# 733     -71.0551
# 744     -71.0816
# 745     -71.0587
# 747     -71.1090
# 748     -71.0456
# 754     -71.1293
# 755     -71.0983
# 757     -71.0980
# 758     -71.1343
# 759     -71.0899
# 760     -71.1242
# 761     -71.0941
# 762     -71.0755
# 763     -71.0832
# 764     -71.0478
# 765     -71.0339
# 767     -71.0320
# 768     -71.0315
# ...          ...
# 46648   -71.0623
# 46649   -71.0579
# 46652   -71.1148
# 46654   -71.0941
# 46656   -71.0587
# 46657   -71.0587
# 46660   -71.0431
# 46661   -71.1655
# 46663   -71.1428
# 46666   -71.0568
# 46667   -71.0564
# 46669   -71.0640
# 46670   -71.0565
# 46671   -71.0389
# 46672   -71.0805
# 46673   -71.0707
# 46675   -71.0561
# 46676   -71.0355
# 46677   -71.0514
# 46678   -71.1702
# 46679   -71.0347
# 46687   -71.1705
# 46689   -71.0932
# 46690   -71.0641
# 46691   -71.0772
# 46692   -71.0450
# 46693   -71.1061
# 46694   -71.1187
# 46695   -71.0932
# 46697   -71.0932
#
# [27614 rows x 1 columns]

# %%
evaluate_clusters(scaled_snow_cases_XY, 25)

# %%
# Out:
# CASE_TITLE
# Request for Snow Plowing                          18619
# Snow Removal                                       7434
# Requests for Street Cleaning                       1083
# Request for Pothole Repair                          810
# Misc. Snow Complaint                                768
# Schedule a Bulk Item Pickup                         746
# Heat - Excessive  Insufficient                      518
# Empty Litter Basket                                 489
# Traffic Signal Repair                               464
# Request for Snow Plowing (Emergency Responder)      464
# dtype: int64

# %% [markdown]
# -----

# %% [markdown]
# ## Step 3. Detecting outliers

# %% [markdown]
# Now that we have a clustering of the records in the dataset, we can detect the outlying ones. These are the ones who are the farthest from the centroids of their clusters. Track them down and describe any interesting observations that you can make. **(20 pts)**

# %%
import sklearn.cluster as cluster
dbscan = cluster.DBSCAN(eps=10)
dbscan.fit(mdata)
y_pred = dbscan.labels_.astype(np.int)

print y_pred
colors = np.array([x for x in 'bgrcmykbgrcmykbgrcmykbgrcmyk'])
colors = np.hstack([colors] * 20)
plt.scatter(mdata[:, 0], mdata[:, 1], color=colors[y_pred].tolist(), s=10, alpha=0.8)
# Out:
# [0 2 2 ..., 0 1 0]

# %%
# Code for setting the style of the notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("../../theme/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=EB+Garamond' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     .code_cell {
#         width: 105ex !important ;
#         margin-bottom: 15px !important;
#     }
#     div.cell {
#         margin-left: auto;
#         margin-right: auto;
#         width: 70%;
#     }
#     div.cell.selected {
#         border: thin rgba(171, 171, 171, 0.5) dashed;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
#         font-family: 'EB Garamond', serif;
#     }
#     h3 {
#         font-family: 'EB Garamond', serif;
#         margin-top:12px;
#         margin-bottom: 3px;
#     }
#     h4 {
#         font-family: 'EB Garamond', serif;
#     }
#     h5 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     div.text_cell_render {
#         font-family: 'EB Garamond',Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 140%;
#     }
#     div.input_area {
#         border-color: rgba(0,0,0,0.10) !important;
#         background: #fafafa;
#     }
#     .CodeMirror {
#             font-family: "Source Code Pro";
#             font-size: 90%;
#     }
#     .prompt {
#         display: None;
#     }
#     .output {
#         padding-left: 50px;
#         padding-top: 5px;
#     }
#     .output_wrapper {
#         padding-left: 5px;
#         padding-top: inherit;
#     }
#     div.output_scroll {
#         width: inherit;
#     }
#     .inner_cell {
#         padding-left: 5px;
#     }
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 50pt;
#         line-height: 100%;
#         color:#CD2305;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #CD2305;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .warning {
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
